# %% [markdown]
# <h1>Python Pandas - Basic Operations on Dataframe</h1>
# <h4>Reading a Sample .csv File <b>Sales Records.csv</b></h4>

# %%
import pandas as pd 
df=pd.read_csv('Sales Records.csv')
print(df)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# <br><br><li>Get the no of Rows & Columns</li>

# %%
df.shape
# Out:
# (100, 14)

# %%
rows,columns=df.shape

# %% [markdown]
# <br><br><li>Print the first 5 records</li>

# %%
df.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...

# %% [markdown]
# <br><br><li>Print the first 2 records</li>

# %%
df.head(2)
# Out:
#                               Region  Country  Item Type Sales Channel  \
# 0              Australia and Oceania   Tuvalu  Baby Food       Offline
# 1  Central America and the Caribbean  Grenada     Cereal        Online
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              H  5/28/2010  669165933  6/27/2010        9925      255.28
# 1              C  8/22/2012  963881480  9/15/2012        2804      205.70
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     159.42      2533654.0  1582243.50     951410.50
# 1     117.11       576782.8   328376.44     248406.36

# %% [markdown]
# <br><br><li>Print the last 5 records</li>

# %%
df.tail()
# Out:
#               Order Date              Region      Item Type Sales Channel  \
# Country
# Mali           7/26/2011  Sub-Saharan Africa        Clothes        Online
# Malaysia      11/11/2011                Asia         Fruits       Offline
# Sierra Leone    6/1/2016  Sub-Saharan Africa     Vegetables       Offline
# Mexico         7/30/2015       North America  Personal Care       Offline
# Mozambique     2/10/2012  Sub-Saharan Africa      Household       Offline
#
#              Order Priority   Order ID   Ship Date  Units Sold  Unit Price  \
# Country
# Mali                      M  512878119    9/3/2011         888      109.28
# Malaysia                  L  810711038  12/28/2011        6267        9.33
# Sierra Leone              C  728815257   6/29/2016        1485      154.06
# Mexico                    M  559427106    8/8/2015        5767       81.73
# Mozambique                L  665095412   2/15/2012        5367      668.27
#
# ...

# %% [markdown]
# <br><br><li>Print the records b/w 2nd & 5th rows</li>

# %%
df[2:5]
# Out:
#                Region                Country        Item Type Sales Channel  \
# 2              Europe                 Russia  Office Supplies       Offline
# 3  Sub-Saharan Africa  Sao Tome and Principe           Fruits        Online
# 4  Sub-Saharan Africa                 Rwanda  Office Supplies       Offline
#
#   Order Priority Order Date   Order ID Ship Date  Units Sold  Unit Price  \
# 2              L   5/2/2014  341417157  5/8/2014        1779      651.21
# 3              C  6/20/2014  514321792  7/5/2014        8102        9.33
# 4              L   2/1/2013  115456712  2/6/2013        5062      651.21
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 2     524.96     1158502.59   933903.84     224598.75
# 3       6.92       75591.66    56065.84      19525.82
# 4     524.96     3296425.02  2657347.52     639077.50

# %% [markdown]
# <br><br><li>Print the entire rows</li>

# %%
df[:]
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
df
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# <br><br><li>Print the columns</li>

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %% [markdown]
# <br><br><li>Print a particular column say 'Country'</li>

# %%
df.Country
# Out:
# 0                    Tuvalu
# 1                   Grenada
# 2                    Russia
# 3     Sao Tome and Principe
# 4                    Rwanda
#               ...
# 95                     Mali
# 96                 Malaysia
# 97             Sierra Leone
# 98                   Mexico
# 99               Mozambique
# Name: Country, Length: 100, dtype: object

# %% [markdown]
# <br><br><li>Print a particular column say 'Region'</li>

# %%
df['Region']
# Out:
# 0                 Australia and Oceania
# 1     Central America and the Caribbean
# 2                                Europe
# 3                    Sub-Saharan Africa
# 4                    Sub-Saharan Africa
#                     ...
# 95                   Sub-Saharan Africa
# 96                                 Asia
# 97                   Sub-Saharan Africa
# 98                        North America
# 99                   Sub-Saharan Africa
# Name: Region, Length: 100, dtype: object

# %% [markdown]
# <br><br><li>Check type of a column -- usually a column of a Dataframe is of type 'Series'</li>

# %%
type(df['Order Date'])
# Out:
# pandas.core.series.Series

# %%
df['Ship Date']
# Out:
# 0      6/27/2010
# 1      9/15/2012
# 2       5/8/2014
# 3       7/5/2014
# 4       2/6/2013
#          ...
# 95      9/3/2011
# 96    12/28/2011
# 97     6/29/2016
# 98      8/8/2015
# 99     2/15/2012
# Name: Ship Date, Length: 100, dtype: object

# %% [markdown]
# <br><br><li>Print a particular columns say 'Country' & 'Units Sold'</li>

# %%
df[['Country','Units Sold']].head(10)
# Out:
#                  Country  Units Sold
# 0                 Tuvalu        9925
# 1                Grenada        2804
# 2                 Russia        1779
# 3  Sao Tome and Principe        8102
# 4                 Rwanda        5062
# 5        Solomon Islands        2974
# 6                 Angola        4187
# 7           Burkina Faso        8082
# 8  Republic of the Congo        6070
# 9                Senegal        6593

# %% [markdown]
# <br><br><li>Get max value of the 'Units Sold' Column</li>

# %%
df['Units Sold'].max()
# Out:
# 9925

# %% [markdown]
# <br><br><li>Get min value of the 'Units Sold' Column</li>

# %%
df['Units Sold'].min()
# Out:
# 124

# %% [markdown]
# <br><br><b>Get most of the statistics regarding a table</b>

# %%
df.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %% [markdown]
# <br><br><li>Get rows with 'Units Sold' less than a value</li>

# %%
df[df['Units Sold']<200000000]
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# <br><br><li>Get rows with max value of 'Unit Cost'</li>

# %%
df[df['Unit Cost']==df['Unit Cost'].max()]
# Out:
#                           Region       Country        Item Type Sales Channel  \
# 2                         Europe        Russia  Office Supplies       Offline
# 4             Sub-Saharan Africa        Rwanda  Office Supplies       Offline
# 32         Australia and Oceania     Australia  Office Supplies        Online
# 38                          Asia        Brunei  Office Supplies        Online
# 39                        Europe      Bulgaria  Office Supplies        Online
# 49            Sub-Saharan Africa    Mauritania  Office Supplies       Offline
# 53            Sub-Saharan Africa  Sierra Leone  Office Supplies       Offline
# 62            Sub-Saharan Africa      Cameroon  Office Supplies        Online
# 68                        Europe     Lithuania  Office Supplies       Offline
# 70                          Asia  Turkmenistan  Office Supplies        Online
# 90            Sub-Saharan Africa  Sierra Leone  Office Supplies       Offline
# ...

# %% [markdown]
# <br><br><li>Get the row with max value of 'Total Profit'</li>

# %%
df[df['Total Profit']==df['Total Profit'].max()]
# Out:
#                           Region   Country  Item Type Sales Channel  \
# 74  Middle East and North Africa  Pakistan  Cosmetics       Offline
#
#    Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 74              L   7/5/2013  231145322  8/16/2013        9892       437.2
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# 74     263.33      4324782.4  2604860.36    1719922.04

# %% [markdown]
# <br><br><li>Get the 'Order Date' with max value of 'Total Revenue'</li>

# %%
df[['Order Date']][df['Total Revenue']==df['Total Revenue'].max()]
# Out:
#    Order Date
# 13   2/8/2017

# %% [markdown]
# <br><br><li>Change default index (0,1,2,3..) with 'Order Date' column</li>

# %%
df.set_index('Order Date',inplace=True)
# Out:
#                                        Region                Country  \
# Order Date
# 5/28/2010               Australia and Oceania                 Tuvalu
# 8/22/2012   Central America and the Caribbean                Grenada
# 5/2/2014                               Europe                 Russia
# 6/20/2014                  Sub-Saharan Africa  Sao Tome and Principe
# 2/1/2013                   Sub-Saharan Africa                 Rwanda
# ...                                       ...                    ...
# 7/26/2011                  Sub-Saharan Africa                   Mali
# 11/11/2011                               Asia               Malaysia
# 6/1/2016                   Sub-Saharan Africa           Sierra Leone
# 7/30/2015                       North America                 Mexico
# 2/10/2012                  Sub-Saharan Africa             Mozambique
#
#                   Item Type Sales Channel Order Priority   Order ID  \
# Order Date
# ...

# %% [markdown]
# <br><br><li>Filter By 'Order Date' column after changing index</li>

# %%
df.loc['5/2/2014']
# Out:
# Region                     Europe
# Country                    Russia
# Item Type         Office Supplies
# Sales Channel             Offline
# Order Priority                  L
# Order ID                341417157
# Ship Date                5/8/2014
# Units Sold                   1779
# Unit Price                 651.21
# Unit Cost                  524.96
# Total Revenue          1158502.59
# Total Cost              933903.84
# Total Profit            224598.75
# Name: 5/2/2014, dtype: object

# %% [markdown]
# <br><br><li>Changing index back to default stage</li>

# %%
df.reset_index(inplace=True) 
df
# Out:
#     Order Date                             Region                Country  \
# 0    5/28/2010              Australia and Oceania                 Tuvalu
# 1    8/22/2012  Central America and the Caribbean                Grenada
# 2     5/2/2014                             Europe                 Russia
# 3    6/20/2014                 Sub-Saharan Africa  Sao Tome and Principe
# 4     2/1/2013                 Sub-Saharan Africa                 Rwanda
# ..         ...                                ...                    ...
# 95   7/26/2011                 Sub-Saharan Africa                   Mali
# 96  11/11/2011                               Asia               Malaysia
# 97    6/1/2016                 Sub-Saharan Africa           Sierra Leone
# 98   7/30/2015                      North America                 Mexico
# 99   2/10/2012                 Sub-Saharan Africa             Mozambique
#
#           Item Type Sales Channel Order Priority   Order ID   Ship Date  \
# ...

# %% [markdown]
# <br><br><li>Setting index as 'Country' Column </li>

# %%
df.set_index('Country',inplace=True)
df
# Out:
#                        Order Date                             Region  \
# Country
# Tuvalu                  5/28/2010              Australia and Oceania
# Grenada                 8/22/2012  Central America and the Caribbean
# Russia                   5/2/2014                             Europe
# Sao Tome and Principe   6/20/2014                 Sub-Saharan Africa
# Rwanda                   2/1/2013                 Sub-Saharan Africa
# ...                           ...                                ...
# Mali                    7/26/2011                 Sub-Saharan Africa
# Malaysia               11/11/2011                               Asia
# Sierra Leone             6/1/2016                 Sub-Saharan Africa
# Mexico                  7/30/2015                      North America
# Mozambique              2/10/2012                 Sub-Saharan Africa
#
#                              Item Type Sales Channel Order Priority  \
# Country
# ...

# %% [markdown]
# <br><br><li>Searching by new index 'Country' column with 'Mexico' value</li>

# %%
df.loc['Mexico']
# Out:
#         Order Date         Region      Item Type Sales Channel Order Priority  \
# Country
# Mexico   11/6/2014  North America      Household       Offline              C
# Mexico   2/17/2012  North America  Personal Care       Offline              L
# Mexico   7/30/2015  North America  Personal Care       Offline              M
#
#           Order ID   Ship Date  Units Sold  Unit Price  Unit Cost  \
# Country
# Mexico   986435210  12/12/2014        6954      668.27     502.54
# Mexico   430915820   3/20/2012        6422       81.73      56.67
# Mexico   559427106    8/8/2015        5767       81.73      56.67
#
#          Total Revenue  Total Cost  Total Profit
# Country
# Mexico      4647149.58  3494663.16    1152486.42
# Mexico       524870.06   363934.74     160935.32
# Mexico       471336.91   326815.89     144521.02
